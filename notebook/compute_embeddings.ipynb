# %% [markdown]
# # Put the embeddings in the database
# This notebook will compute the embeddings for the articles in the database. It will then insert the embeddings into the database.
#
# ## Steps
#
# 1. Find the posts that have not been embedded yet
# 2. Compute the embeddings for those posts
# 3. Insert the embeddings into the database

# %%
import psycopg2

# Connect to the database
conn = psycopg2.connect("dbname=hn user=julien")

# Open a cursor to perform database operations
cur = conn.cursor()

# Query the database and obtain data as Python objects
cur.execute("""
    SELECT id, title, text
    FROM hn_article
    LEFT JOIN hn_embeddings USING(id)
    WHERE hn_embeddings.id IS NULL
    AND text IS NOT NULL
    LIMIT 100000;
            """)

articles = cur.fetchall()
len(articles)
# Out:
# 438

# %%
from openai import AsyncAzureOpenAI
from os import getenv
from tiktoken import get_encoding
import dotenv

# We load the environment variables.
dotenv.load_dotenv(override=True)

# Set to a global variable to avoid calling the function every time.
enc = get_encoding("cl100k_base")

# We define the proxies to use.
proxies = {
    'http': getenv("PROXY_URL_USA"),
    'https': getenv("PROXY_URL_USA"),
}

# Constants
# The maximum number of tokens we will use to compute embeddings.
MAX_TOKENS = 3072
DIMENSIONS = 1536  # The number of dimensions of the embeddings.
MODEL_ID = "text-embedding-ada-002"  # The ID of the model to use.

client = AsyncAzureOpenAI(
    api_version= getenv("AZURE_AI_VERSION"),
    azure_endpoint=getenv("AZURE_AI_ENDPOINT"),
    azure_deployment=getenv("AZURE_DEPLOYMENT_ID"),
    api_key=getenv("AZURE_AI_API_KEY"),
)

def get_text_truncated_tokenized(text: str, max_tokens: int) -> str:
    """
    Truncate a text to the desired number of tokens.
    It's to avoid excessive costs when computing embeddings.

    Args:
        text (str): The text to truncate.
        max_tokens (int): The maximum number of tokens in cl100k_base

    """
    # We tokenize the text.
    tokens = enc.encode(text, disallowed_special=())

    # We truncate the tokens.
    tokens = tokens[:max_tokens]

    # We decode the tokens.
    text = enc.decode(tokens)

    # As stated here: https://learn.microsoft.com/en-us/azure/cognitive-services/openai/reference#embeddings
    # It's best to replace newlines with spaces.
    text = text.replace("\n", " ")

    return text

async def compute_embeddings(text: str) -> list[float]:
    """
    Compute the embeddings of a URL from the text of the article.
    First, we get the text of the article.
    Then, we shrink the text to MAX_TOKENS tokens.
    Finally, we compute the embeddings of the text.

    The dimension for text-embedding-ada-002 is 1536.

    Args:
        url (str): The URL of the article.

    Returns:
        list[float]: The embeddings of the article.
    """
    text = get_text_truncated_tokenized(text, MAX_TOKENS)

    if (len(text) == 0):
        raise Exception("Text extracted is empty.")

    # We compute the embeddings.
    response = (await client.embeddings.create(input=text, model=MODEL_ID, encoding_format="float")).data[0].embedding

    return response

# %%
async def compute_embeddings_for_article(article: tuple[int, str, str]) -> None:
    """
    Compute the embeddings for a list of articles.

    Args:
        articles (list[tuple[int, str, str]]): The list of articles to compute the embeddings for.
    """
    id = article[0]
    title = article[1]
    text = article[2]

    toEmbed = title + " " + text
    embeddings = None
    try:
        embeddings = await compute_embeddings(toEmbed)
    except Exception as e:
        print(f"Error while computing embeddings for article {id}: {e}")
        return
    
    # We insert the embeddings in the database.
    try:
        cur.execute("""
            INSERT INTO hn_embeddings(id, embedding)
            VALUES (%s, %s);
            """, (id, embeddings))
        conn.commit()
        print(f"Successfully inserted embeddings for article {id} {title}")
    except Exception as e:
        conn.rollback()
        print(f"Error while inserting embeddings for article {id}: {e}")
        return

# %%
import aiometer

# We compute the embeddings for the articles.
await aiometer.run_on_each(compute_embeddings_for_article, articles, max_per_second=5)
# Out:
# Successfully inserted embeddings for article 38637853 microsoft/windows-ai-studio
# Successfully inserted embeddings for article 38722246 Beeper - Moving Forward
# Successfully inserted embeddings for article 38759257 GTA 5 source code leaks online, giving Rockstar a huge blow on Christmas: Report
# Successfully inserted embeddings for article 38719736 US homelessness up 12% to highest reported level as rents soar and coronavirus pandemic aid lapses
# Successfully inserted embeddings for article 38755412 Did English ever have a formal version of "you"?
# Successfully inserted embeddings for article 155400 Some Heroes
# Successfully inserted embeddings for article 38730107 LABS.GOOGLE
# Successfully inserted embeddings for article 38687997 Providing HTML Content Using Htmx
# Successfully inserted embeddings for article 38629630 Bash One-Liners for LLMs
# Successfully inserted embeddings for article 38581959 Scrambling Eggs for Spotify with Knuth's Fibonacci Hashing
# Successfully inserted embeddings for article 38670729 Internet Explorer is Evil: The story
# Successfully inserted embeddings for article 38579890 The surprising connection between after-hours work and decreased productivity
# Successfully inserted embeddings for article 38716032 Catalyst
# Successfully inserted embeddings for article 38616591 Motorola's Pioneering 8-bit 6800 : Origins and Architecture
# Successfully inserted embeddings for article 38612164 Role-playing with AI will be a powerful tool for writers and educators
# Successfully inserted embeddings for article 38677344 Qatar Airways Bans YouTuber For Negative Review
# Successfully inserted embeddings for article 38673654 US nuclear-fusion lab enters new era: achieving ‘ignition’ over and over
# Successfully inserted embeddings for article 38664729 SSH3: faster and rich secure shell using HTTP/3
# Successfully inserted embeddings for article 38590156 A Very Big Small Leap Forward in Graph Theory
# Successfully inserted embeddings for article 38588012 American workers keep proving they don’t need to return to the office to be productive. A Big Four economist pinpoints 4 factors driving the productivity explosion
# Successfully inserted embeddings for article 38622476 GM Says It's Dropping Apple CarPlay And Android Auto Because They're Unsafe (Update)
# Successfully inserted embeddings for article 38734909 The Hyperloop was always a scam
# Successfully inserted embeddings for article 38778386 Donald Knuth’s 2023 Christmas Lecture: Making the Cells Dance
# Successfully inserted embeddings for article 38760477 Ruby 3.3.0 Released
# Successfully inserted embeddings for article 38848566 Venomous snake bites kill thousands every year. A California doctor may have a solution
# Successfully inserted embeddings for article 38866622 kelas/ooj
# Successfully inserted embeddings for article 38837888 We Could Fix Everything, We Just Don't
# Successfully inserted embeddings for article 38813677 I made JSX for Lua (because I hate static sites)
# Successfully inserted embeddings for article 38769416 Croquet for Unity: Live, network-transparent 3D gaming... but it's so much more
# Successfully inserted embeddings for article 38788273 No new iPhone? No secure iOS: Looking at an unfixed iOS vulnerability
# Successfully inserted embeddings for article 38784994 Comedian Tom Smothers, one-half of the Smothers Brothers, dies at 86
# Successfully inserted embeddings for article 38743719 Make a song about the moon.
# Successfully inserted embeddings for article 38834895 PyPy has moved to Git, GitHub
# Successfully inserted embeddings for article 38865079 Silenzio! ‘Anna’s Archive’ Shadow Library Blocked Following Publishers’ Complaint
# Successfully inserted embeddings for article 38777460 An interactive map of Chicago's zoning code, by
# Successfully inserted embeddings for article 38872362 What We Got Right, What We Got Wrong
# Successfully inserted embeddings for article 38850202 SIEVE is simpler than LRU
# Successfully inserted embeddings for article 38870207 facebookresearch/audio2photoreal
# Successfully inserted embeddings for article 38859427 Full-Time Wanderer: My 3-Year Experiment as a Digital Nomad
# Successfully inserted embeddings for article 38842079 An Untold Story of LSD Psychotherapy in Communist Czechoslovakia
# Successfully inserted embeddings for article 38833881 Pluralistic: 2024's public domain is a banger (20 Dec 2023)
# Successfully inserted embeddings for article 38778007 laptop of the magi: an annoyed iMessage antitrust anecdote
# Successfully inserted embeddings for article 38838369 Running 9front on an emulated SGI Indy via MAME
# Successfully inserted embeddings for article 38839506 What I've learned about flow fields so far.
# Successfully inserted embeddings for article 38749170 Crown shyness
# Successfully inserted embeddings for article 38835345 iorate/ublacklist
# Successfully inserted embeddings for article 38873878 Google illegally refusing to bargain with employee union, says NLRB
# Successfully inserted embeddings for article 38781535 Berliner IT-Experten hacken Teslas Autopilot und finden geheimen Elon-Modus
# Successfully inserted embeddings for article 38828040 ublue-os/bazzite
# Successfully inserted embeddings for article 38875318 binkley/modern-java-practices
# Successfully inserted embeddings for article 38783112 Operation Triangulation: The last (hardware) mystery
# Successfully inserted embeddings for article 38782636 Scientists discover the first new antibiotics in over 60 years using AI
# Successfully inserted embeddings for article 38780519 hrvach/deskhop
# Successfully inserted embeddings for article 38791870 37C3: Unlocked
# Successfully inserted embeddings for article 38779968 Thanks to This Man, Airplanes Don’t Crash Into Mountains Anymore
# Successfully inserted embeddings for article 38756888 "Attention", "Transformers", in Neural Network "Large Language Models"
# Successfully inserted embeddings for article 38838945 Push Notifications - What to Push, What Not to Push, and How Often
# Successfully inserted embeddings for article 38823101 How I forked SteamOS for my living room PC
# Successfully inserted embeddings for article 38818734 EU CRA: What does it mean for open source?
# Successfully inserted embeddings for article 38849580 Mozilla CEO pockets a packet, asks biz to pick up pace the 'Mozilla way'
# Successfully inserted embeddings for article 38857396 The Drive Stats of Backblaze Storage Pods
# Successfully inserted embeddings for article 38758355 Cray 1 Supercomputer Performance Comparisons With Home Computers Phones and Tablets
# Successfully inserted embeddings for article 38768645 Let it snow()
# Successfully inserted embeddings for article 38760120 The C++20 Naughty and Nice List for Game Devs
# Successfully inserted embeddings for article 38748087 Huge 2TB microSD card is on the way, sounds perfect for your Steam Deck
# Successfully inserted embeddings for article 38831083 Orange Site Hit
# Successfully inserted embeddings for article 38856751 Are roads the biggest driver of ecological destruction? An interview with Ben Goldfarb
# Successfully inserted embeddings for article 38848001 Thoughts on PostgreSQL in 2024
# Successfully inserted embeddings for article 38747710 Storyteller
# Successfully inserted embeddings for article 38793414 The Best Reason to Use Firefox Is Sync That Actually Works
# Successfully inserted embeddings for article 38744296 This 2,300-year-old mosaic made of shells and coral has just been found buried under Rome
# Successfully inserted embeddings for article 38742637 joaovitoriasilva/endurain
# Successfully inserted embeddings for article 38780716 Introducing `rep` & `ren`: A New Approach to Command-Line Find & Replace, and Renaming
# Successfully inserted embeddings for article 38750459 Unveiling the big leap in Ruby 3.3's IRB
# Successfully inserted embeddings for article 38810073 A Functional Language with Effect Types and Handlers
# Successfully inserted embeddings for article 38768997 The Life and Death of Open Source Companies
# Successfully inserted embeddings for article 38869235 goat telling me to slow down when I talk too fast
# Successfully inserted embeddings for article 38734164 LED Industrial Piercing
# Successfully inserted embeddings for article 38793015 It's not microservice or monolith; it's cognitive load you need to understand first
# Successfully inserted embeddings for article 38844945 90x faster than pgvector — Lantern's HNSW Index Creation Time
# Successfully inserted embeddings for article 38822973 You’re Supposed To Be Glad Your Tesla Is A Brittle Heap Of Junk
# Successfully inserted embeddings for article 38841328 A New Approach to Local Multiplayer / Splitscreen Perspective With Raytracing
# Successfully inserted embeddings for article 38768262 What are farm animals thinking?
# Successfully inserted embeddings for article 38795735 Repurposing Hugo as a wiki
# Successfully inserted embeddings for article 38847581 A simulation of me: fine-tuning an LLM on 240k text messages
# Successfully inserted embeddings for article 38852534 Making the Micropipette
# Successfully inserted embeddings for article 38797640 Tracking developer build times to decide if the M3 MacBook is worth upgrading
# Successfully inserted embeddings for article 38851642 terminal smooth scrolling
# Successfully inserted embeddings for article 38732862 Do I really need to get out the soldering-iron again?
# Successfully inserted embeddings for article 38802152 40% of US electricity is now emissions-free
# Successfully inserted embeddings for article 38877321 YouTube demonetizes public domain 'Steamboat Willie' video after copyright claim
# Successfully inserted embeddings for article 38808552 A Core Calculus for Documents
# Successfully inserted embeddings for article 38780522 2023: Focusing on a single product pays off
# Successfully inserted embeddings for article 38720544 Google OAuth is broken (sort of)
# Successfully inserted embeddings for article 38728278 How To Turn Off Google’s “Privacy Sandbox” Ad Tracking—and Why You Should
# Successfully inserted embeddings for article 38787892 jasonjmcghee/rem
# Successfully inserted embeddings for article 38784817 HyperRogue 13.0
# Successfully inserted embeddings for article 38759875 reforming-unix.adoc
# Successfully inserted embeddings for article 38736525 3,500 arrested, $300M seized in global cybercrime crackdown
# Successfully inserted embeddings for article 38769850 Black Triangles
# Successfully inserted embeddings for article 38833208 Happy Public Domain Day 2024!
# Successfully inserted embeddings for article 38850651 attractivechaos/plb2
# Successfully inserted embeddings for article 38839763 Blog 〉The funny rules of SpamAssassin in 2023 (deep dive)
# Successfully inserted embeddings for article 38725167 Apple wants AI to run directly on its hardware instead of in the cloud
# Successfully inserted embeddings for article 38745667 Hbomberguy Didn’t Want to Make That 4-Hour Plagiarism Video
# Successfully inserted embeddings for article 38771185 How gas utilities used tobacco tactics to avoid gas stove regulations
# Successfully inserted embeddings for article 38777553 Operation Snow White
# Successfully inserted embeddings for article 38808163 Open Source Liability is Coming
# Successfully inserted embeddings for article 38822892 Ottopot
# Successfully inserted embeddings for article 38885758 0000000
# Successfully inserted embeddings for article 38884517 Apple rejects the HEY Calendar from their App Store
# Successfully inserted embeddings for article 38928265 You Don’t Need More Resilience. You Need Friends. And Money.
# Successfully inserted embeddings for article 38937801 Does DNA have the equivalent of IF-statements, WHILE loops, or function calls? How about GOTO?
# Successfully inserted embeddings for article 38933021 Potent psychedelic drug banishes PTSD, small study finds
# Successfully inserted embeddings for article 38930011 Paula Vennells: Ex-Post Office boss handing back CBE over IT scandal
# Successfully inserted embeddings for article 38912125 IT Employment Grew by Just 700 Jobs in 2023, Down From 267,000 in 2022
# Successfully inserted embeddings for article 38902414 The browsers biggest TLS mistake
# Successfully inserted embeddings for article 38898104 Teachable Machine
# Successfully inserted embeddings for article 38945437 Thousands of Software Engineers Say the Job Market Is Getting Much Worse
# Successfully inserted embeddings for article 38929967 It’s Not Just Seafood: New Study Finds Microplastics in Nearly 90% of Proteins Sampled, Including Plant-Based Meat Alternatives
# Successfully inserted embeddings for article 38889820 YS-L/csvlens
# Error while computing embeddings for article 38925704: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38890540: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38945125: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38893534: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38948642: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38917307: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38959026: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38956323: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38902042: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38940374: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38882726: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38942847: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38951084: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38956314: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38928951: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38956623: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38941747: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38959248: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38957961: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38929917: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38906966: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38892164: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38958798: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38958534: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38899183: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38952214: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38951802: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38921441: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38905019: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38891721: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38959480: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38900843: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38929369: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38933999: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38895373: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38954189: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38955018: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38961377: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38924549: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38959762: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38923015: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38929677: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38935605: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38903145: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38904963: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38938616: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38896896: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38943040: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38932603: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38887531: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38898934: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38942400: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38956861: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38905178: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38921518: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38934013: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38891712: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38935048: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38922040: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38925307: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38934666: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38932509: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38958266: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38961463: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38906989: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38961080: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38911740: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38926978: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38911227: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38947654: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38901089: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38889774: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38915999: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38896027: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 2 seconds. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38962647: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38891177: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38892685: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38953846: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38908427: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38928334: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38883094: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38918310: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38917175: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38828594: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# ...
# Error while computing embeddings for article 38914356: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Error while computing embeddings for article 38924159: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Successfully inserted embeddings for article 38885567 Dennis Ritchie on & | vs. ==
# Successfully inserted embeddings for article 38912497 Twilio CEO Lawson steps down after bruising activist battles
# Successfully inserted embeddings for article 38929474 Everything wrong with databases and why their complexity is now unnecessary
# Error while computing embeddings for article 38912406: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Successfully inserted embeddings for article 38904418 With higher fees and more ads, streaming services like Netflix, Disney+ and Hulu are cashing in by using the old tactics of cable TV
# Error while computing embeddings for article 38919884: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Successfully inserted embeddings for article 38952897 We've detected unusual activity from your computer network
# Error while computing embeddings for article 38888527: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Successfully inserted embeddings for article 38902258 Behind the scenes: the struggle for each paper
# Successfully inserted embeddings for article 38894208 Adventures of Linux Userspace at Meta
# Successfully inserted embeddings for article 38956581 Feynman's Nobel Ambition
# Error while computing embeddings for article 38907568: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Successfully inserted embeddings for article 38911088 LinguaCafe
# Successfully inserted embeddings for article 38898143 1️⃣🐝🏎️ The One Billion Row Challenge - .NET Edition
# Successfully inserted embeddings for article 38963197 psst: Paper-based Secret Sharing Technique
# Error while computing embeddings for article 38897475: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Successfully inserted embeddings for article 38948091 epoll: The API that powers the modern internet
# Successfully inserted embeddings for article 38899922 Simple lasts longer: making a map stateful using scotch tape and Web Storage API
# Error while computing embeddings for article 38925952: Error code: 429 - {'error': {'code': '429', 'message': 'Requests to the Embeddings_Create Operation under Azure OpenAI API version 2023-10-01-preview have exceeded call rate limit of your current OpenAI S0 pricing tier. Please retry after 1 second. Please go here: https://aka.ms/oai/quotaincrease if you would like to further increase the default rate limit.'}}
# Successfully inserted embeddings for article 38920043 DataFrames for the new era
# Successfully inserted embeddings for article 38918279 Duolingo Cuts 10% of Contractors as It Uses More AI to Create App Content
# Successfully inserted embeddings for article 38916647 Trade-offs between Different CRDTs
# Successfully inserted embeddings for article 38916663 The Eight Golden Rules of Interface Design
# Successfully inserted embeddings for article 38915673 OpenAI and journalism
# Successfully inserted embeddings for article 38900069 7 lessons from building 9 startups in 2023
# Successfully inserted embeddings for article 38905898 What does the Cerebellum Do Anyway?
# Successfully inserted embeddings for article 38925928 gscept/nebula
# Successfully inserted embeddings for article 38895623 adamkarvonen/chess_llm_interpretability
# Successfully inserted embeddings for article 38956842 Majority of debtors to US hospitals now people with health insurance
# Successfully inserted embeddings for article 38931559 Contra Wirecutter on the IKEA air purifier
# Successfully inserted embeddings for article 38954867 A Guide to Logical Replication and CDC in PostgreSQL
# Successfully inserted embeddings for article 38890705 grahame/pharus
# Successfully inserted embeddings for article 38893684 About Behind The Screens
# Successfully inserted embeddings for article 38938402 The lost language extensions of MetaWare's High C Compiler
# Successfully inserted embeddings for article 38950466 I Found David Lynch’s Lost Dune II Script
# Successfully inserted embeddings for article 38903074 Disney backs down from 'Steamboat Willie' YouTube copyright claim
# Successfully inserted embeddings for article 38955274 U.S. EIA: Solar Will Supply Almost All Growth in U.S. Electricity Generation through 2025
# Successfully inserted embeddings for article 38901504 Build a custom workspace with modular apps
# Successfully inserted embeddings for article 38936102 atuinsh/atuin
# Successfully inserted embeddings for article 38951399 Hackers can infect network-connected wrenches to install ransomware
# Successfully inserted embeddings for article 38935485 ambulancja/mariposa
# Successfully inserted embeddings for article 38930746 FTC bans X-Mode from selling phone location data, and orders firm to delete collected data
# Successfully inserted embeddings for article 38916212 Solver performance: 1989 vs 2024
# Successfully inserted embeddings for article 38890692 The best way to get unstuck
# Successfully inserted embeddings for article 38893456 Chess-GPT's Internal World Model
# Successfully inserted embeddings for article 38911407 Money Pours Into New Fabs And Facilities
# Successfully inserted embeddings for article 38900197 The New York Times Launches a Very Strong Case Against Microsoft and OpenAI
# Successfully inserted embeddings for article 38937129 Intro
# Successfully inserted embeddings for article 38923741 Python 3.13 gets a JIT
# Successfully inserted embeddings for article 38942867 Remember Netflix’s $1m algorithm contest? Well, here’s why it didn’t use the winning entry.
# Successfully inserted embeddings for article 38889156 systemd through the eyes of a musl distribution maintainer
# Successfully inserted embeddings for article 38902407 The Gist: Coimisiún na Meán go off the rails
# Successfully inserted embeddings for article 38912032 Apple Vision Pro available in the U.S. on February 2
# Successfully inserted embeddings for article 38923627 Where have all the websites gone?
# Successfully inserted embeddings for article 38899987 CARD GAME RULES
# Successfully inserted embeddings for article 38908956 The Biggest Smallest PNG
# Successfully inserted embeddings for article 38938414 AMD Reveals Next-Gen Desktop Processors for Extreme PC Gaming and Creator Performance
# Successfully inserted embeddings for article 38913649 Tuna species popular in sashimi and poke bowls in sharp decline in the Indian Ocean
# Successfully inserted embeddings for article 38958955 Let's Block It!
# Successfully inserted embeddings for article 38885054 TinyLlama: An Open-Source Small Language Model
# Successfully inserted embeddings for article 38925802 Give a brain to your game's NPCs
# Successfully inserted embeddings for article 38893614 NIST Identifies Types of Cyberattacks That Manipulate Behavior of AI Systems
# Successfully inserted embeddings for article 38946188 How to get coworkers to stop giving me ChatGPT-generated suggestions
# Successfully inserted embeddings for article 38934824 Edge of Emulation: Glucoboy
# Successfully inserted embeddings for article 38899290 Useful utilities and services over DNS
# Successfully inserted embeddings for article 38905280 When Random Numbers Are Too Random: Low Discrepancy Sequences
# Successfully inserted embeddings for article 38939114 Redeployment Part One
# Successfully inserted embeddings for article 38931282 Ancient Stars Made Extraordinarily Heavy Elements
# Successfully inserted embeddings for article 38903869 Just because you can doesn't mean you should: the <meter> element
# Successfully inserted embeddings for article 38921668 iv :2
# Successfully inserted embeddings for article 38905889 The optimal amount of fraud is non-zero
# Successfully inserted embeddings for article 38920738 Macs can now inform Apple if any liquids have been detected in the USB-C ports
# Successfully inserted embeddings for article 38909735 The Phrase "No Evidence" Is A Red Flag For Bad Science Communication
# Successfully inserted embeddings for article 38904574 awslabs/amazon-kinesis-video-streams-webrtc-sdk-c
# Successfully inserted embeddings for article 38896096 warmcat/libwebsockets
# Successfully inserted embeddings for article 38901012 First new vax in ...30 years? :-)
# Successfully inserted embeddings for article 38968269 Stock Market News, Jan. 12, 2024: Bank Stocks Drop After Earnings Roll In
# Successfully inserted embeddings for article 38968550 We need technology that is less immersive, not more
# Successfully inserted embeddings for article 38965509 We removed advertising cookies, here’s what happened
# Successfully inserted embeddings for article 38967262 Airbus Shatters Record for Jet Orders as Demand Soars
# Successfully inserted embeddings for article 38965306 Wind turbines are friendlier to birds than oil-and-gas drilling
# Successfully inserted embeddings for article 38977128 A decade long Steam issue, is everyone just too fast for Valve?
# Successfully inserted embeddings for article 38971966 marimo-team/marimo
# Successfully inserted embeddings for article 38966601 CLI User Experience Case Study: Topiary
# Successfully inserted embeddings for article 38975453 Hidden Changes in GPT-4, Uncovered
# Successfully inserted embeddings for article 38971178 Did OpenTelemetry deliver on its promise in 2023?
# Successfully inserted embeddings for article 38964675 Atomics And Concurrency
# Successfully inserted embeddings for article 38969985 Linux Gains An Open File Server Implementation For Tractors & Agriculture Machinery
# Successfully inserted embeddings for article 38972735 OpenAI Quietly Deletes Ban on Using ChatGPT for “Military and Warfare”
# Successfully inserted embeddings for article 38969348 Autophage rocket engine consumes plastic fuselage for fuel
# Successfully inserted embeddings for article 38976955 All styles →
# Successfully inserted embeddings for article 38965310 Inner Speech
# Successfully inserted embeddings for article 38966145 Is Fortran "a dead language"?
# Successfully inserted embeddings for article 38975204 revng/revng
# Successfully inserted embeddings for article 38969114 Carta's 83(b) Oversight: A Tax Trap for Married Startup Employees
# Successfully inserted embeddings for article 38975226 microsoft/xbox-multiplayer-analysis-tool
# Successfully inserted embeddings for article 38969759 Features and Benefits of Bluetooth Mesh 1.1 for Wireless Mesh Networking
# Successfully inserted embeddings for article 38966875 Post Office lied and threatened BBC over Horizon whistleblower
# Successfully inserted embeddings for article 38969461 A vision for the alleviation of water scarcity in the US Southwest and the revitalization of the Salton Sea
# Successfully inserted embeddings for article 38977692 How to be More Agentic
# Successfully inserted embeddings for article 38978705 Updates on Grounding of Boeing 737 MAX 9 Aircraft
# Successfully inserted embeddings for article 38972362 There has never been a better time to game on Linux
# Successfully inserted embeddings for article 38963678 Log in to TikTok
# Successfully inserted embeddings for article 38964958 Writeup: Keycloak open redirect (CVE-2023-6927)
# Successfully inserted embeddings for article 38964983 Huge ancient city found in the Amazon
# Successfully inserted embeddings for article 38976254 derrickburns/generalized-kmeans-clustering
# Successfully inserted embeddings for article 38968619 [REPOST] Epistemic Learned Helplessness
# Successfully inserted embeddings for article 38971221 Vector Databases A Technical Primer
# Successfully inserted embeddings for article 38978665 v2.5.0
# Successfully inserted embeddings for article 38972358 FrigadeHQ/remote-storage
# Successfully inserted embeddings for article 38965003 McFly - fly through your shell history
# Successfully inserted embeddings for article 38978289 Compiler Frontend Engineer
# Successfully inserted embeddings for article 38969893 TRIPS: Trilinear Point Splatting for Real-Time Radiance Field Rendering arXiv
# Successfully inserted embeddings for article 38967744 Changes we’re making to Google Assistant
# Successfully inserted embeddings for article 38967684 Amazing AI 12+
# Successfully inserted embeddings for article 38969072 ESP32-C61: Delivering Affordable Wi-Fi 6 Connectivity
# Successfully inserted embeddings for article 38964972 Unity’s Open-Source Double Standard: the ban of VLC
# Successfully inserted embeddings for article 38972153 Welcome!
# Successfully inserted embeddings for article 38966035 Statement regarding the ongoing SourceHut outage
# Successfully inserted embeddings for article 38977532 Build your component library
# Successfully inserted embeddings for article 38971811 Apple knew AirDrop users could be identified and tracked as early as 2019, researchers say
# Successfully inserted embeddings for article 38969466 US regulator grounds 737 Max 9 until it receives further data from Boeing
# Successfully inserted embeddings for article 38980171 Japan ANA Boeing 737-800 flight turns back due to cockpit window crack
# Successfully inserted embeddings for article 38974404 SLEEPER AGENTS: TRAINING DECEPTIVE LLMS THAT PERSIST THROUGH SAFETY TRAINING
# Successfully inserted embeddings for article 38748370 About The Book
# Successfully inserted embeddings for article 38672112 What is Ventoy
# Successfully inserted embeddings for article 38806270 In 2024, please switch to Firefox
# Successfully inserted embeddings for article 38748120 Par 1.53.0
# Successfully inserted embeddings for article 38775579 macos-fuse-t/fuse-t

# %%
countTokens = 0

tokenArr = []
for article in articles:
    count = len(enc.encode(article[1] + " " + article[2], disallowed_special=()))
    countTokens += min(count, 3072)
    tokenArr.append(min(count, 3072))


print(f"Average number of tokens per article: {countTokens / len(articles)}")

tokenArr.sort()
print(f"Median number of tokens per article: {tokenArr[len(tokenArr) // 2]}")
# Quartiles
print(f"First quartile of tokens per article: {tokenArr[len(tokenArr) // 4]}")
print(f"Third quartile of tokens per article: {tokenArr[len(tokenArr) // 4 * 3]}")

# Max
print(f"Max number of tokens per article: {tokenArr[-1]}")

# Sum
print(f"Total number of tokens: {countTokens}")
# Out:
# Average number of tokens per article: 1561.9597701149426
# Median number of tokens per article: 1373
# First quartile of tokens per article: 654
# Third quartile of tokens per article: 2711
# Max number of tokens per article: 3072
# Total number of tokens: 1087124
