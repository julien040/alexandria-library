# %% [markdown]
# # Put the embeddings in the database
# This notebook will compute the embeddings for the articles in the database. It will then insert the embeddings into the database.
#
# ## Steps
#
# 1. Find the posts that have not been embedded yet
# 2. Compute the embeddings for those posts
# 3. Insert the embeddings into the database

# %%
import psycopg2

# Connect to the database
conn = psycopg2.connect("dbname=hn user=julien")

# Open a cursor to perform database operations
cur = conn.cursor()

# Query the database and obtain data as Python objects
cur.execute("""
    SELECT id, title, text
    FROM hn_article
    LEFT JOIN hn_embeddings USING(id)
    WHERE hn_embeddings.id IS NULL
    AND text IS NOT NULL
    LIMIT 100000;
            """)

articles = cur.fetchall()
len(articles)
# Out:
# 0

# %%
sumLen = 0
for article in articles:
    sumLen += len(article[2])

print(sumLen / len(articles), "is the average length of the articles")
# Out:
# 15198.727272727272 is the average length of the articles

# %%
from openai import AsyncAzureOpenAI
from os import getenv
from tiktoken import get_encoding
import dotenv

# We load the environment variables.
dotenv.load_dotenv(override=True)

# Set to a global variable to avoid calling the function every time.
enc = get_encoding("cl100k_base")

# We define the proxies to use.
""" proxies = {
    'http': getenv("PROXY_URL_USA"),
    'https': getenv("PROXY_URL_USA"),
} """

# Constants
# The maximum number of tokens we will use to compute embeddings.
MAX_TOKENS = 3072
DIMENSIONS = 1536  # The number of dimensions of the embeddings.
MODEL_ID = "text-embedding-ada-002"  # The ID of the model to use.

client = AsyncAzureOpenAI(
    api_version= getenv("AZURE_AI_VERSION"),
    azure_endpoint=getenv("AZURE_AI_ENDPOINT"),
    azure_deployment=getenv("AZURE_DEPLOYMENT_ID"),
    api_key=getenv("AZURE_AI_API_KEY"),
)

def get_text_truncated_tokenized(text: str, max_tokens: int) -> str:
    """
    Truncate a text to the desired number of tokens.
    It's to avoid excessive costs when computing embeddings.

    Args:
        text (str): The text to truncate.
        max_tokens (int): The maximum number of tokens in cl100k_base

    """
    # We tokenize the text.
    tokens = enc.encode(text, disallowed_special=())

    # We truncate the tokens.
    tokens = tokens[:max_tokens]

    # We decode the tokens.
    text = enc.decode(tokens)

    # As stated here: https://learn.microsoft.com/en-us/azure/cognitive-services/openai/reference#embeddings
    # It's best to replace newlines with spaces.
    text = text.replace("\n", " ")

    return text

async def compute_embeddings(text: str) -> list[float]:
    """
    Compute the embeddings of a URL from the text of the article.
    First, we get the text of the article.
    Then, we shrink the text to MAX_TOKENS tokens.
    Finally, we compute the embeddings of the text.

    The dimension for text-embedding-ada-002 is 1536.

    Args:
        url (str): The URL of the article.

    Returns:
        list[float]: The embeddings of the article.
    """
    text = get_text_truncated_tokenized(text, MAX_TOKENS)

    if (len(text) == 0):
        raise Exception("Text extracted is empty.")

    # We compute the embeddings.
    response = (await client.embeddings.create(input=text, model=MODEL_ID, encoding_format="float")).data[0].embedding

    return response

# %%
async def compute_embeddings_for_article(article: tuple[int, str, str]) -> None:
    """
    Compute the embeddings for a list of articles.

    Args:
        articles (list[tuple[int, str, str]]): The list of articles to compute the embeddings for.
    """
    id = article[0]
    title = article[1]
    text = article[2]

    toEmbed = title + " " + text
    embeddings = None
    try:
        embeddings = await compute_embeddings(toEmbed)
    except Exception as e:
        print(f"Error while computing embeddings for article {id}: {e}")
        return
    
    # We insert the embeddings in the database.
    try:
        cur.execute("""
            INSERT INTO hn_embeddings(id, embedding)
            VALUES (%s, %s);
            """, (id, embeddings))
        conn.commit()
        print(f"Successfully inserted embeddings for article {id} {title}")
    except Exception as e:
        conn.rollback()
        print(f"Error while inserting embeddings for article {id}: {e}")
        return

# %%
import aiometer

# We compute the embeddings for the articles.
await aiometer.run_on_each(compute_embeddings_for_article, articles, max_per_second=4)
# Out:
# Successfully inserted embeddings for article 41173486 Parody site ClownStrike refused to bow to CrowdStrike’s bogus DMCA takedown
# Successfully inserted embeddings for article 41192247 Introducing Qwen2-Math
# Successfully inserted embeddings for article 41326039 Leveraging AI for efficient incident response
# Successfully inserted embeddings for article 41294354 Court Sees Through California’s ‘Protect The Children’ Ruse, Strikes Down Kids Code
# Successfully inserted embeddings for article 41309072 Rye and uv: August is Harvest Season for Python Packaging
# Successfully inserted embeddings for article 41125980 pytorch/torchchat
# Successfully inserted embeddings for article 41310508 makeecat/Peng
# Successfully inserted embeddings for article 41361281 Erasure Coding for Distributed Systems
# Successfully inserted embeddings for article 41472135 Richard Feynman and The Connection Machine
# Successfully inserted embeddings for article 41405961 All content is © 2006 - 2015 by o.gelbrich / neckcns.com, except where stated otherwise. Impressum Tapedeck.org was built using webdesign tools from webdesignerstoolkit.com.
# Successfully inserted embeddings for article 41195823 Isometric Projection in Game Development
# Successfully inserted embeddings for article 41253461 Exact Polygonal Filtering
# Successfully inserted embeddings for article 41287425 Archiving “The Famous Computer Cafe”
# Successfully inserted embeddings for article 41336690 Japan on edge of EUV lithography chip-making revolution
# Successfully inserted embeddings for article 41169195 WordStar 7, the last ever DOS version, is re-released for free
# Successfully inserted embeddings for article 41183795 Imagining a Personal Data Pipeline
# Successfully inserted embeddings for article 41463809 Did Sandia use a thermonuclear secondary in a product logo?
# Successfully inserted embeddings for article 41224173 Try unrolling a thread yourself!
# Successfully inserted embeddings for article 41332427 My IRC client runs on Kubernetes
# Successfully inserted embeddings for article 41363499 Predicting the Future of Distributed Systems
# Successfully inserted embeddings for article 41439041 Writing a book in the age of open source
# Successfully inserted embeddings for article 41292018 The gigantic and unregulated power plants in the cloud
# Successfully inserted embeddings for article 41209181 Does Deep Live Cam support real-time video stream processing?
# Successfully inserted embeddings for article 41474508 A Post-Google World
# Successfully inserted embeddings for article 41421591 Inductive or Deductive? Rethinking the Fundamental Reasoning Abilities of LLMs
# Successfully inserted embeddings for article 41434315 Why bother with argv[0]?
# Successfully inserted embeddings for article 41458508 Deploying Rust in Existing Firmware Codebases
# Successfully inserted embeddings for article 41238632 Google Pixel Watch 3: bigger, brighter, fine-tuned for fitness
# Successfully inserted embeddings for article 41233811 dplanitzer/Serena
# Successfully inserted embeddings for article 41239913 Rust Atomics and Locks
# Successfully inserted embeddings for article 41238392 What I Learned Writing an Album in Just Intonation
# Successfully inserted embeddings for article 41436009 Resurfacing the past
# Successfully inserted embeddings for article 41235259 jbunke/stipple-effect
# Successfully inserted embeddings for article 41327567 A symbol for the ⁂ fediverse
# Successfully inserted embeddings for article 41290994 Tales from the Far Side
# Successfully inserted embeddings for article 41313740 US hospital told family their daughter had checked out when in fact she’d died
# Successfully inserted embeddings for article 41284322 Leaving Neovim for Zed
# Successfully inserted embeddings for article 41444700 reMarkable - The future of paper is here
# Successfully inserted embeddings for article 41425259 SuperIlu/DOjS
# Successfully inserted embeddings for article 41231141 bbum's rants, code & references
# Successfully inserted embeddings for article 41183240 Type Unions for C#
# Successfully inserted embeddings for article 41177831 The Private Life: On James Baldwin
# Successfully inserted embeddings for article 41244172 CSVs Are Kinda Bad. DSVs Are Kinda Good.
# Successfully inserted embeddings for article 41286753 When Serial Isn't RS-232, and Geocaching with the Garmin GPS 95
# Successfully inserted embeddings for article 41319224 async2 - The .NET Runtime Async experiment concludes
# Successfully inserted embeddings for article 41192118 Firefox Sidebar and Vertical tabs: try them out in Nightly Firefox Labs 131
# Successfully inserted embeddings for article 41380154 Signal Is More Than Encrypted Messaging. Under Meredith Whittaker, It’s Out to Prove Surveillance Capitalism Wrong
# Successfully inserted embeddings for article 41415651 Postgres webhooks with pgstream
# Successfully inserted embeddings for article 41182395 Zen5's AVX512 Teardown + More...
# Successfully inserted embeddings for article 41311135 You don't know how bad most things are nor precisely how they're bad.
# Successfully inserted embeddings for article 41206443 How Rivian reduced electrical wiring by 1.6 miles and 44 pounds
# Successfully inserted embeddings for article 41135240 Oscar, an open-source contributor agent architecture
# Successfully inserted embeddings for article 41302475 uv: Unified Python packaging
# Successfully inserted embeddings for article 41292757 DRAKON
# Successfully inserted embeddings for article 41196554 National Park Service Will Cite Drivers Of AWD Cars For Driving On 4WD-Only Trails
# Successfully inserted embeddings for article 41436642 The Hidden Engineering of Landfills
# Successfully inserted embeddings for article 41357123 Leader Election With S3 Conditional Writes
# Successfully inserted embeddings for article 41309997 Why a Hedge Fund Built Its Own Database
# Successfully inserted embeddings for article 41173719 Google says it is obligated to disclose confidential information of users to U.S. government
# Successfully inserted embeddings for article 41175586 pv_controller.go
# Successfully inserted embeddings for article 41211091 Antifragility in complex dynamical systems
# Successfully inserted embeddings for article 41410442 QRSVG
# Successfully inserted embeddings for article 41227987 SQL Injection Isn't Dead: Smuggling Queries at the Protocol Level
# Successfully inserted embeddings for article 41290237 Bit-banging a BASIC Birthday
# Successfully inserted embeddings for article 41295923 Artificial intelligence is losing hype
# Successfully inserted embeddings for article 41381569 TOUGHBOOK 40
# Successfully inserted embeddings for article 41387674 Only Metalcraft Heaters give
# Successfully inserted embeddings for article 41415023 Founder Mode
# Successfully inserted embeddings for article 41347501 7 Things I Learned From Doing Triathlon In My 70s
# Successfully inserted embeddings for article 41209994 supabase/pg_replicate
# Successfully inserted embeddings for article 41212616 We’re Entering an AI Price-Fixing Dystopia
# Successfully inserted embeddings for article 41207182 Caltech Team Develops First Noninvasive Method to Continually Measure True Blood Pressure
# Successfully inserted embeddings for article 41425446 What Does It Really Mean to Learn?
# Successfully inserted embeddings for article 41260603 Slow is Smooth, Smooth is Fast: Navy SEALs’ Efficiency Secret
# Successfully inserted embeddings for article 41441159 Court handcuffs employees with non-compete agreements — again
# Successfully inserted embeddings for article 41182847 Announcing Official Puppeteer Support for Firefox
# Successfully inserted embeddings for article 41447317 mem0ai/mem0
# Successfully inserted embeddings for article 41263143 Stanford_ECON295⧸CS323_I_2024_I_The_Age_of_AI,_Eric_Schmidt.txt
# Successfully inserted embeddings for article 41148002 Probability Estimates of a 21st Century AMOC
# Successfully inserted embeddings for article 41242095 Basic MetaProgramming in Zig
# Successfully inserted embeddings for article 41406799 This month in Servo: tabbed browsing, Windows buffs, devtools, and more!
# Successfully inserted embeddings for article 41236993 Reversing the AMD Secure Processor (PSP) - Part 2: Cryptographic Co-Processor (CCP)
# Successfully inserted embeddings for article 41213151 The surveilled society: Who is watching you and how
# Successfully inserted embeddings for article 41388326 Computer Scientists Prove That Heat Destroys Quantum Entanglement
# Successfully inserted embeddings for article 41429245 An Iranian writer is sentenced to 12 years after tweeting a dot at the supreme leader
# Successfully inserted embeddings for article 41316999 Celebrating 6 years since Valve announced Steam Play Proton for Linux
# Successfully inserted embeddings for article 41272213 Save or export your private and public Slack messages, threads, files, and users locally without admin privileges.
# Successfully inserted embeddings for article 41201922 How Base 3 Computing Beats Binary
# Successfully inserted embeddings for article 41431888 Apache Zeppelin
# Successfully inserted embeddings for article 41372833 5000x faster CRDTs: An Adventure in Optimization
# Successfully inserted embeddings for article 41282798 Journal of Behavioral Decision Making
# Successfully inserted embeddings for article 41443493 DAGitty — draw and analyze causal diagrams
# Successfully inserted embeddings for article 41300888 Software Possession for Personal Use
# Successfully inserted embeddings for article 41312084 Code review antipatterns
# Successfully inserted embeddings for article 41404733 Rust for Linux revisited August 30, 2024 on Drew DeVault's blog
# Successfully inserted embeddings for article 41338124 Explosion-Scratch/firebuilder
# Successfully inserted embeddings for article 41406669 Iron as an inexpensive storage medium for hydrogen
# Successfully inserted embeddings for article 41444855 nuno-faria/tetris-sql
# Successfully inserted embeddings for article 41445803 Exploring Goja: A Golang JavaScript Runtime
# Successfully inserted embeddings for article 41384144 Build native apps for iPhone and Android with Skip
# Successfully inserted embeddings for article 41454779 Porting systemd to musl libc-powered Linux
# Successfully inserted embeddings for article 41336462 HumbleUI/HumbleUI
# Successfully inserted embeddings for article 41429960 QWERTY-Flip
# Successfully inserted embeddings for article 41318408 No "Hello", No "Quick Call", and no Meetings Without an Agenda
# Successfully inserted embeddings for article 41338776 Small strings in Rust
# Successfully inserted embeddings for article 41174281 YC Fall 2024 batch applications due by 8/27
# Successfully inserted embeddings for article 41316067 Bum Farto
# Successfully inserted embeddings for article 41330258 OpenSSH Backdoors
# Successfully inserted embeddings for article 41241942 Sort, sweep, and prune: Collision detection algorithms
# Successfully inserted embeddings for article 41461850 Overview

# %%
countTokens = 0

tokenArr = []
for article in articles:
    count = len(enc.encode(article[1] + " " + article[2], disallowed_special=()))
    countTokens += min(count, 3072)
    tokenArr.append(min(count, 3072))


print(f"Average number of tokens per article: {countTokens / len(articles)}")

tokenArr.sort()
print(f"Median number of tokens per article: {tokenArr[len(tokenArr) // 2]}")
# Quartiles
print(f"First quartile of tokens per article: {tokenArr[len(tokenArr) // 4]}")
print(f"Third quartile of tokens per article: {tokenArr[len(tokenArr) // 4 * 3]}")

# Max
print(f"Max number of tokens per article: {tokenArr[-1]}")

# Sum
print(f"Total number of tokens: {countTokens}")
# Out:
# Average number of tokens per article: 2010.209090909091
# Median number of tokens per article: 2085
# First quartile of tokens per article: 1027
# Third quartile of tokens per article: 3072
# Max number of tokens per article: 3072
# Total number of tokens: 221123
